# %% [markdown]
# <a href="https://colab.research.google.com/github/KN-Vignesh/Projects/blob/main/Customer_Churn_Prediction_with_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dependency

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE  ##Synthetic Minority over-sampling technique
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import pickle

# %% [markdown]
# Data loading

# %%
df = pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.shape
# Out:
# (7043, 21)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df = df.drop(columns=['customerID'])

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
print(df['gender'].unique())
# Out:
# ['Female' 'Male']

# %%
for col in df.columns:
  print(col, df[col].unique() )
  print('-'* 50)
# Out:
# gender ['Female' 'Male']
# --------------------------------------------------
# SeniorCitizen [0 1]
# --------------------------------------------------
# Partner ['Yes' 'No']
# --------------------------------------------------
# Dependents ['No' 'Yes']
# --------------------------------------------------
# tenure [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
# --------------------------------------------------
# PhoneService ['No' 'Yes']
# --------------------------------------------------
# MultipleLines ['No phone service' 'No' 'Yes']
# --------------------------------------------------
# InternetService ['DSL' 'Fiber optic' 'No']
# --------------------------------------------------
# OnlineSecurity ['No' 'Yes' 'No internet service']
# --------------------------------------------------
# ...

# %%
print(df.isnull().sum())
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df['TotalCharges']=df['TotalCharges'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_795/2003555289.py in <cell line: 0>()
# ----> 1 df['TotalCharges']=df['TotalCharges'].astype(float)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
len(df[df['TotalCharges'] == ' '])
# Out:
# 11

# %%
df['TotalCharges'] = df['TotalCharges'].replace(' ', '0.0')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %% [markdown]
# # Checking the Class distribution of target column

# %%
print(df['Churn'].value_counts())
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# Exploratory Data Analysis

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# Numeriacal Features and Analysis

# %%
def plot_histogram(df,column_name):
  plt.figure(figsize = (5,3))
  sns.histplot(df[column_name],kde=True)
  plt.title = (f'Distribution of {column_name}')
  # calculate the mean and median values for the columns
  col_mean = df[column_name].mean()
  col_median = df[column_name].median()
  # add verticle lines for the mean and median
  plt.axvline(col_mean, color='red', linestyle='--', linewidth=1, label="Mean")
  plt.axvline(col_median, color='green', linestyle='-', linewidth=1, label="Median")
  plt.legend()
  plt.show()

# %%
plot_histogram(df,'tenure')

# %%
plot_histogram(df,'MonthlyCharges')

# %%
plot_histogram(df,'TotalCharges')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_795/1654482591.py in <cell line: 0>()
# ----> 1 plot_histogram(df,'TotalCharges')
#
# /tmp/ipykernel_795/1034988019.py in plot_histogram(df, column_name)
#       4   plt.title = (f'Distribution of {column_name}')
#       5   # calculate the mean and median values for the columns
# ----> 6   col_mean = df[column_name].mean()
#       7   col_median = df[column_name].median()
#       8   # add verticle lines for the mean and median
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6547         **kwargs,
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#    6551     @doc(make_doc("median", ndim=1))
#
# ...

# %% [markdown]
# Box plot for numerical features

# %%
def plot_boxplot(df,column_name):
  plt.figure(figsize = (5,3))
  sns.boxplot(df[column_name])
  plt.title = (f'Box plot of {column_name}')
  plt.ylabel(column_name)
  plt.show()

# %%
plot_boxplot(df,'tenure')

# %%
plot_boxplot(df,'MonthlyCharges')

# %%
plot_boxplot(df,'TotalCharges')

# %% [markdown]
# Corelation Heatmap for numerical columns

# %%
plt.figure(figsize = (10,8))
sns.heatmap(df[['tenure','MonthlyCharges', 'TotalCharges']].corr(),annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %% [markdown]
# Count plot for categorical columns

# %%
object_cols = df.select_dtypes(include='object').columns.to_list()
object_cols = ['SeniorCitizen'] + object_cols

for col in object_cols:
  plt.figure(figsize = (5,3))
  sns.countplot(x=df[col])
  plt.title = (f'Count plot of {col}')
  plt.show()

# %% [markdown]
# Data preprocessing

# %%
df.head(3)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges TotalCharges Churn
# ...

# %% [markdown]
# Label encoding of target column

# %%
df['Churn'] = df['Churn'].replace({'No': 0, 'Yes': 1})

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %% [markdown]
# Label Encoding of categorical features

# %%
object_columns = df.select_dtypes(include='object').columns
print(object_columns)
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'TotalCharges'],
#       dtype='object')

# %%
#initialize a dictionary to save the encoders

encoders = {}

# Get object columns, excluding 'Churn' as it's already encoded correctly.
object_columns_to_encode = [col for col in df.select_dtypes(include='object').columns if col != 'Churn']

#apply label encoding and store the encoders
for column in object_columns_to_encode:
  label_encoder = LabelEncoder()
  df[column] = label_encoder.fit_transform(df[column])
  encoders[column] = label_encoder

  with open('encoders.pkl', 'wb') as f:
    pickle.dump(encoders, f)

# %%
encoders
# Out:
# {'gender': LabelEncoder(),
#  'Partner': LabelEncoder(),
#  'Dependents': LabelEncoder(),
#  'PhoneService': LabelEncoder(),
#  'MultipleLines': LabelEncoder(),
#  'InternetService': LabelEncoder(),
#  'OnlineSecurity': LabelEncoder(),
#  'OnlineBackup': LabelEncoder(),
#  'DeviceProtection': LabelEncoder(),
#  'TechSupport': LabelEncoder(),
#  'StreamingTV': LabelEncoder(),
#  'StreamingMovies': LabelEncoder(),
#  'Contract': LabelEncoder(),
#  'PaperlessBilling': LabelEncoder(),
#  'PaymentMethod': LabelEncoder(),
#  'TotalCharges': LabelEncoder()}

# %% [markdown]
# Training and test data split

# %%
# splitting the features and targets

x = df.drop(columns=['Churn'])
y=df['Churn']

# %%
print(y)
# Out:
# 0       2
# 1       2
# 2       1
# 3       2
# 4       1
#        ..
# 7038    2
# 7039    2
# 7040    2
# 7041    1
# 7042    2
# Name: Churn, Length: 7043, dtype: int64

# %%
# split training and test data

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(y_train)
# Out:
# 2142    2
# 1623    2
# 6074    1
# 1362    1
# 6754    2
#        ..
# 3772    1
# 5191    2
# 5226    2
# 5390    1
# 860     2
# Name: Churn, Length: 5634, dtype: int64

# %% [markdown]
# Synthetic Minority Oversampling TEchnique (SMOTE)

# %%
smote = SMOTE(random_state=42)

# %%
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
print(y_train_smote.value_counts())
# Out:
# Churn
# 2    4138
# 1    4138
# Name: count, dtype: int64

# %% [markdown]
# Model Training

# %% [markdown]
# Training with default hyper parameters

# %%
## Include Hyper parameter training and Stratified K Folding code

# %%
# dictionary of model

models_dict = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'XGBoost': XGBClassifier(random_state=42)
}

# %%
# dictionary to store the cross validation results

cv_scores = {}

# perform 5 fold cross validation for each model
for model_name, model_instance in models_dict.items():
  print(f'Training {model_name} with default parameters.')
  scores = cross_val_score(model_instance, X_train_smote, y_train_smote, cv=5, scoring='accuracy')
  cv_scores[model_name] = scores
  print(f'{model_name} cross validation accuracy: {np.mean(scores):.2f}')
# Out:
# Training Decision Tree with default parameters.
# Decision Tree cross validation accuracy: 0.79
# Training Random Forest with default parameters.
# Random Forest cross validation accuracy: 0.84
# Training XGBoost with default parameters.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_795/500561340.py in <cell line: 0>()
#       6 for model_name, model_instance in models_dict.items():
#       7   print(f'Training {model_name} with default parameters.')
# ----> 8   scores = cross_val_score(model_instance, X_train_smote, y_train_smote, cv=5, scoring='accuracy')
#       9   cv_scores[model_name] = scores
#      10   print(f'{model_name} cross validation accuracy: {np.mean(scores):.2f}')
#
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# ...

# %%
cv_scores
# Out:
# {'Decision Tree': array([0.68538647, 0.72507553, 0.82356495, 0.84350453, 0.85015106]),
#  'Random Forest': array([0.72161836, 0.77160121, 0.90271903, 0.89063444, 0.89728097])}

# %%
rfc = RandomForestClassifier(random_state=42)

# %%
rfc.fit(X_train_smote,y_train_smote)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_795/1478170135.py in <cell line: 0>()
# ----> 1 model.fit(X_train_smote,y_train_smote)
#
# /usr/local/lib/python3.13/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     567             for k, arg in zip(sig.parameters, args):
#     568                 kwargs[k] = arg
# --> 569             return func(**kwargs)
#     570
#     571         return inner_f
#
# /usr/local/lib/python3.13/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1810                 or not (classes == expected_classes).all()
#    1811             ):
# -> 1812                 raise ValueError(
#    1813                     f"Invalid classes inferred from unique values of `y`.  "
# ...

# %% [markdown]
# Model Evaluation

# %%
# Evaluate on test data

y_test_pred = model.predict(X_test)

print(f'Accuracy Score:\n',accuracy_score(y_test,y_test_pred))
print(f'Confusion Matrix:\n',confusion_matrix(y_test,y_test_pred))
print(f'Classification Report:\n',classification_report(y_test,y_test_pred))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_795/704732071.py in <cell line: 0>()
#       1 # Evaluate on test data
#       2
# ----> 3 y_test_pred = model.predict(X_test)
#       4
#       5 print(f'Accuracy Score:\n',accuracy_score(y_test,y_test_pred))
#
# /usr/local/lib/python3.13/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     567             for k, arg in zip(sig.parameters, args):
#     568                 kwargs[k] = arg
# --> 569             return func(**kwargs)
#     570
#     571         return inner_f
#
# /usr/local/lib/python3.13/dist-packages/xgboost/sklearn.py in predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1891     ) -> ArrayLike:
#    1892         with config_context(verbosity=self.verbosity):
# -> 1893             class_probs = super().predict(
#    1894                 X=X,
# ...

# %%
# save the trained model as pickel file
with open("customer_churn_model.pkl", "wb") as f:
    pickle.dump(rfc, f)
#
